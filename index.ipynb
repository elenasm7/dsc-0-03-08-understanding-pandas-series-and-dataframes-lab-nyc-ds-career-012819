# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
df = df.rename(str.lower, axis='columns')
df
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# ...

# %% [markdown]
# # Change the Index to be the Line Names

# %%
#Your code here
df = df.set_index('linename')

# %% [markdown]
# # Painstakingly change the index back

# %%
# Your code here
df = df.reset_index()

# %%
df.dtypes
# Out:
# linename                                                                object
# c/a                                                                     object
# unit                                                                    object
# scp                                                                     object
# station                                                                 object
# division                                                                object
# date                                                                    object
# time                                                                    object
# desc                                                                    object
# entries                                                                  int64
# exits                                                                    int64
# dtype: object

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
df['Num_Lines'] = df.apply(lambda row: len(row.linename), axis=1)
df
# Out:
#        linename    c/a  unit       scp        station division        date  \
# 0       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 1       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 2       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 3       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 4       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 5       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 6       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 7       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 8       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 9       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 10      NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# ...

# %%
df['date'] = pd.to_datetime(df['date'],format="%m/%d/%Y")

# %%
df_new = df[['Date', 'Entries','Exits']]
df_new = df_new.diff(axis=0)

df_new = df_new[['Entries','Exits']]

# %%
df_new.columns = ['Entries_Diff','Exits_Diff']
df_new
# Out:
#         Entries_Diff  Exits_Diff
# 0                NaN         NaN
# 1               20.0         4.0
# 2               18.0        41.0
# 3               75.0        85.0
# 4              169.0        70.0
# 5              213.0        41.0
# 6              121.0        35.0
# 7               13.0         1.0
# 8                9.0        22.0
# 9               41.0        41.0
# 10             127.0        63.0
# 11             194.0        44.0
# 12              69.0        25.0
# 13              10.0         2.0
# 14              23.0        78.0
# 15             132.0       229.0
# 16             252.0        60.0
# 17             704.0        66.0
# 18             173.0        30.0
# 19              12.0         5.0
# 20              32.0        90.0
# 21             147.0       186.0
# 22             265.0        23.0
# 23             744.0        53.0
# 24             174.0        30.0
# 25               8.0         4.0
# 26              35.0        88.0
# ...

# %%
#df_with_difference = pd.concat([df, df_new], axis=1, sort=False)

# %%
df_with_difference.groupby('Date').sum()
# Out:
#                   Entries         Exits  Num_Lines  Entries_Diff   Exits_Diff
# Date
# 2018-08-25  1115661545514  909142081474      74725   669429040.0  490627998.0
# 2018-08-26  1192306179082  959223750461      75306  -702007979.0 -518038324.0
# 2018-08-27  1114237052454  911938153513      76110     5839053.0    3435110.0
# 2018-08-28  1143313287046  942230721477      77303     5127401.0    4016404.0
# 2018-08-29  1123655222441  920630864687      75713    -8160361.0    1506764.0
# 2018-08-30  1122723988662  920691927110      76607    18987964.0   11959081.0
# 2018-08-31  1110224700078  906799065337      75573     4054369.0    4210131.0

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.title().strip()
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['Linename', 'C/A', 'Unit', 'Scp', 'Station', 'Division', 'Date', 'Time',
#        'Desc', 'Entries', 'Exits', 'Num_Lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
dates_df = df.groupby('Date').sum()

# %%
dates_df['net_travels'] = dates_df['Entries'] - dates_df['Exits']
#dates_df.dtypes
#dates_df.Exits

# %%
import calendar
dates_df = dates_df.reset_index()
dates_df['weekday'] = dates_df.Date.dt.dayofweek
dates_df
# Out:
#         Date        Entries         Exits  Num_Lines   net_travels  weekday
# 0 2018-08-25  1115661545514  909142081474      74725  206519464040        5
# 1 2018-08-26  1192306179082  959223750461      75306  233082428621        6
# 2 2018-08-27  1114237052454  911938153513      76110  202298898941        0
# 3 2018-08-28  1143313287046  942230721477      77303  201082565569        1
# 4 2018-08-29  1123655222441  920630864687      75713  203024357754        2
# 5 2018-08-30  1122723988662  920691927110      76607  202032061552        3
# 6 2018-08-31  1110224700078  906799065337      75573  203425634741        4

# %%
dates_df['Day'] = dates_df.apply(lambda x: calendar.day_name[x.Date.weekday()],axis=1)
                                                             
# dates_df = dates_df.reset_index()

# %%
dates_df = dates_df.drop(['weekday'], axis=1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
days = dates_df.groupby('Day').sum()
days.plot(kind='barh')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
# days = days.reset_index()
#days.dtypes
#days['IsWeekend'] = days['Day'].map({'Monday':False,'Tuesday':False,'Wednesday':False,3:False,4:False,5:True,6:True})
# wkend = days.groupby('IsWeekend').mean()
# wkend[['Entries', 'Exits']].plot(kind='barh')
#days = days.drop('index',axis='columns')
days
# Out:
#          Day        Entries         Exits  Num_Lines   net_travels IsWeekend
# 0     Friday  1110224700078  906799065337      75573  203425634741       NaN
# 1     Monday  1114237052454  911938153513      76110  202298898941       NaN
# 2   Saturday  1115661545514  909142081474      74725  206519464040       NaN
# 3     Sunday  1192306179082  959223750461      75306  233082428621       NaN
# 4   Thursday  1122723988662  920691927110      76607  202032061552       NaN
# 5    Tuesday  1143313287046  942230721477      77303  201082565569       NaN
# 6  Wednesday  1123655222441  920630864687      75713  203024357754       NaN

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
